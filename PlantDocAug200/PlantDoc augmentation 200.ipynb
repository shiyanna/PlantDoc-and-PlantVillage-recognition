# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
import os

# %%
# !git clone https://github.com/pratikkayal/PlantDoc-Dataset
# Out:
# Cloning into 'PlantDoc-Dataset'...
# remote: Enumerating objects: 2670, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 2670 (delta 23), reused 41 (delta 22), pack-reused 2628
# Receiving objects: 100% (2670/2670), 932.92 MiB | 17.17 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Updating files: 100% (2581/2581), done.

# %%
base_dir = '/content/PlantDoc-Dataset'
#!find $dir_base -type d -print

# %%
dir_train=os.path.join(base_dir, 'train')
dir_test=os.path.join(base_dir, 'test')

# %%
for plant_train in os.listdir(dir_train):
  i=0
  for plant_test in os.listdir(dir_test):
    i+=1
    if(plant_train==plant_test):
      print(plant_train)
      print('  train:',len(os.listdir(os.path.join(dir_train, plant_train))))
      print('  test:',len(os.listdir(os.path.join(dir_test, plant_test))))
      break
    else:
      if i==len(os.listdir(dir_test)):
        print('НЕТ в test',plant_train)
# Out:
# Tomato leaf yellow virus
#   train: 70
#   test: 6
# Potato leaf early blight
#   train: 109
#   test: 8
# Squash Powdery mildew leaf
#   train: 124
#   test: 6
# Corn leaf blight
#   train: 180
#   test: 12
# Tomato leaf late blight
#   train: 101
#   test: 10
# Tomato Early blight leaf
#   train: 79
#   test: 9
# Potato leaf late blight
#   train: 97
#   test: 8
# Strawberry leaf
#   train: 88
#   test: 8
# Tomato leaf bacterial spot
#   train: 101
#   test: 9
# Corn Gray leaf spot
#   train: 64
#   test: 4
# Tomato mold leaf
#   train: 85
#   test: 6
# Apple rust leaf
#   train: 79
#   test: 10
# Tomato leaf mosaic virus
#   train: 44
#   test: 10
# Soyabean leaf
#   train: 57
#   test: 8
# Cherry leaf
#   train: 47
#   test: 10
# НЕТ в test Tomato two spotted spider mites leaf
# grape leaf
#   train: 57
#   test: 12
# Peach leaf
#   train: 103
#   test: 9
# Apple leaf
#   train: 82
#   test: 9
# Bell_pepper leaf spot
#   train: 62
#   test: 9
# Blueberry leaf
#   train: 106
# ...

# %%
import shutil

shutil.rmtree(os.path.join(dir_train, 'Tomato two spotted spider mites leaf'))

# %%
#print(len(os.listdir('/content/PlantDoc-Dataset/test/Tomato two spotted spider mites leaf')))

# %%
datagen = ImageDataGenerator(
    rotation_range=70,
    horizontal_flip=True) # Произвольный поворот по горизонтали

# %%
#test

import scipy
from scipy import ndimage
import numpy as np
import imageio
import math


#for plant_train in os.listdir(dir_train):
plant_train='Corn Gray leaf spot'
i=0
plant_dir=os.path.join(dir_train, plant_train)
n=len(os.listdir(plant_dir))
new_n=300-n
n_range=math.ceil(new_n/n)
sample=math.floor(new_n/n_range)
# print('n',n)
# print('new_n',new_n,sample*n_range)
# print('range',n_range)
# print('sample',sample)

for img in os.listdir(plant_dir):
  if(i<sample):
    path=os.path.join(plant_dir, img)

    image = np.expand_dims(imageio.imread(path), 0)
    datagen.fit(image)
    try:
      for x, val in zip(datagen.flow(image,save_to_dir=plant_dir,save_prefix='aug',save_format='jpg'),range(n_range)) :
        pass
      
    except:
      print(path)
    i+=1
  else:
    print(plant_train,'add')
    break
# Out:
# <ipython-input-9-37a6bac45feb>:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = np.expand_dims(imageio.imread(path), 0)
# /usr/local/lib/python3.9/dist-packages/keras/preprocessing/image.py:2092: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (1, 4, 395, 525) (525 channels).
#   warnings.warn(
# ...

# %%
import scipy
from scipy import ndimage
import numpy as np
import imageio
import math


for plant_train in os.listdir(dir_train):
  i=0
  plant_dir=os.path.join(dir_train, plant_train)
  n=len(os.listdir(plant_dir))
  new_n=200-n
  n_range=math.ceil(new_n/n)
  sample=math.floor(new_n/n_range)
  # print('n',n)
  # print('new_n',new_n,sample*n_range)
  # print('range',n_range)
  # print('sample',sample)

  for img in os.listdir(plant_dir):
    if(i<sample and i<n):
      path=os.path.join(plant_dir, img)
      try:
        image = np.expand_dims(imageio.imread(path), 0)
        datagen.fit(image)
        for x, val in zip(datagen.flow(image,save_to_dir=plant_dir,save_prefix='aug',save_format='jpg'),range(n_range)) :
          pass 
        i+=1 
      except:
        print(path)
      
    else:
      print(plant_train,'add')
      print(i,sample,n_range,new_n)
      break
# Out:
# <ipython-input-8-55050554afbe>:24: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = np.expand_dims(imageio.imread(path), 0)
# Tomato leaf yellow virus add
# 65 65 2 130
# Potato leaf early blight add
# 91 91 1 91
# Squash Powdery mildew leaf add
# 76 76 1 76
# Corn leaf blight add
# 20 20 1 20
# Tomato leaf late blight add
# 99 99 1 99
# Tomato Early blight leaf add
# 60 60 2 121
# Potato leaf late blight add
# 51 51 2 103
# Strawberry leaf add
# 56 56 2 112
# Tomato leaf bacterial spot add
# 99 99 1 99
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
shutil.make_archive('PlantDoc-Dataset200_aug', 'zip', '/content/PlantDoc-Dataset')
# Out:
# '/content/PlantDoc-Dataset200_aug.zip'

# %%
shutil.copyfile('/content/PlantDoc-Dataset200_aug.zip', '/content/drive/MyDrive/Plants Recognition/НИР/Осень 2022/PlantDoc-Dataset200_aug.zip')
# Out:
# '/content/drive/MyDrive/Plants Recognition/НИР/Осень 2022/PlantDoc-Dataset200_aug.zip'
